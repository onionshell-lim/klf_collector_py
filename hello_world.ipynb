# %% [markdown]
# <a href="https://colab.research.google.com/github/onionshell-lim/klf_collector_py/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Tensorflow

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
print(tf.__version__)
# Out:
# 2.20.0
